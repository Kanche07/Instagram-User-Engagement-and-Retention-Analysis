# %%
# installing gdown library
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.29.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.5.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# importing all necessary libraries
import gdown as gd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Importing user metrics Cleaned Dataset from analysis in pg admin**

# %%
# importing "user_metrics" dataset
file_id = "1cwBDZv6tLL7B-8B-XutvlbuVhX6W7RyO"
download_url = f"https://docs.google.com/uc?id={file_id}"

output_file = "user_metrics.csv"

gd.download(download_url, output_file, quiet=False)
user_metrics = pd.read_csv("user_metrics.csv")
# Out:
# Downloading...
# From (original): https://docs.google.com/uc?id=1cwBDZv6tLL7B-8B-XutvlbuVhX6W7RyO
# From (redirected): https://docs.google.com/uc?id=1cwBDZv6tLL7B-8B-XutvlbuVhX6W7RyO&confirm=t&uuid=43b3f6ab-72f6-49fd-b70d-b0ca3cc031d8
# To: /content/user_metrics.csv
# 100%|██████████| 297M/297M [00:02<00:00, 103MB/s]

# %%
user_metrics.shape
# Out:
# (1547896, 28)

# %% [markdown]
# **Correlation Analysis**

# %% [markdown]
# **1. Lifestyle Factors vs Engagement Quality Efficiency (EQE)**

# %%
lifestyle=user_metrics[['sleep_hours_per_night',
                        'exercise_hours_per_week',
                        'perceived_stress_score',
                        'eqe']]

lifestyle_corr=lifestyle.corr()

plt.figure(figsize=(6,3))

sns.heatmap(lifestyle_corr,
            annot=True,
            cmap='Blues')

plt.title('Lifestyle Factors vs EQE')

plt.show()

# %% [markdown]
# **2. Platform Behavior vs Engagement Quality Efficiency (EQE)**

# %%
platform=user_metrics[['sessions_per_day',
                       'daily_active_minutes_instagram',
                       'average_session_length_minutes',
                       'time_on_feed_per_day',
                       'time_on_reels_per_day',
                       'eqe']]

platform_corr=platform.corr()

plt.figure(figsize=(8,4))

sns.heatmap(platform_corr,
            annot=True,
            cmap='Blues')

plt.title('Platform Behavior vs EQE')

plt.show()

# %% [markdown]
# **3. Business Metric Validation (ME, Attention & EQE)**

# %%
business=user_metrics[['me',
                       'attention',
                       'eqe']]

business_corr=business.corr()

plt.figure(figsize=(5,2))

sns.heatmap(business_corr,
            annot=True,
            cmap='coolwarm')

plt.title('Business Metric Validation')

plt.show()

# %% [markdown]
# **OBSERVATIONS:**
#
# *   Higher stress is linked to lower EQE.
#
# *   Excessive platform usage is associated with lower EQE.
#
# *   More meaningful engagement increases EQE, while excessive attention decreases it.
